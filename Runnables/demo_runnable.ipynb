# %%
import random

class DemoLLM:
    def __init__(self):
        print("LLM Created")

    
    def predict(self,prompt):
        response_list = [
            "Delhi is the capital of India",
            "IPL is a cricket league",
            "AI stands for Artificial Intelligence"
        ]

        return {'response' : random.choice(response_list)}

# %%
llm = DemoLLM()
# Out:
# LLM Created

# %%
llm.predict("Capital of India")
# Out:
# {'response': 'IPL is a cricket league'}

# %%
class DemoPromptTemplate:
    def __init__(self,template,input_variable):
        self.template = template
        self.input_variable = input_variable
    
    def format(self,input_dict):
        return self.template.format(**input_dict)

# %%
template = DemoPromptTemplate(
    template = "Write a {length} lines poem about {topic}",
    input_variable = ['topic','length']
)

# %%
prompt = template.format({'topic' : "India", "length" : 5})

# %%
llm.predict(prompt)
# Out:
# {'response': 'IPL is a cricket league'}

# %%
class DemoChain:
    def __init__(self,llm,prompt):
        self.llm = llm
        self.prompt = prompt
    
    def run(self,input_dict):
        final_prompt = self.prompt.format(input_dict)
        result = self.llm.predict(final_prompt)

        return result['response']

# %%
template2 = DemoPromptTemplate(
    template="Write a poem about {topic}",
    input_variable=['topic']
)

# %%
llm2 = DemoLLM()
# Out:
# LLM Created

# %%
chain = DemoChain(llm=llm2,prompt=template2)

# %%
chain.run({"topic" : "India"})
# Out:
# 'IPL is a cricket league'
